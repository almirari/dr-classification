# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification/05_results/eval_baseline.py"
# Out:
# ...
#   01_baseline — Standalone Model Evaluation (CE / CORAL / CORN / Niu)
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification\05_results
#   Device       : cpu
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification\_dataset_extracted
#   Test samples : 367
#
#
# ...
#   Baseline — MobileNetV3-Small (Cross-Entropy)
# ...
#
#   Seed 33 — s1_seed33_best.pth
#   Training best val QWK: 0.8918
#   Evaluating ...
#     batch 12/12
#   QWK=0.8717 | Acc=80.93% | MAE=0.2589 | RMSE=0.6457
#
#   Seed 81 — s1_seed81_best.pth
#   Training best val QWK: 0.8979
#   Evaluating ...
#     batch 12/12
#   QWK=0.8380 | Acc=74.66% | MAE=0.3297 | RMSE=0.7138
#
#   Seed 5 — s1_seed5_best.pth
#   Training best val QWK: 0.8838
#   Evaluating ...
#     batch 12/12
#   QWK=0.8674 | Acc=77.38% | MAE=0.2861 | RMSE=0.6499
#
#   Saved → baseline_ce_test_results.txt
#
#
# ...
#   Baseline — MobileNetV3-Small (CORAL Ordinal)
# ...
#
# ...

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification/05_results/eval_singlekd.py"
# Out:
# ...
#   03_kd_single — Student + Teacher Evaluation
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification\05_results
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification\_dataset_extracted
#   Test samples : 367
#
#
# ############################################################################
#   STUDENT MODELS
# ############################################################################
#
#
# ...
#   Single-Teacher KD — CE  (ResNet-50-CE → MobileNetV3-Small)
# ...
#
#   Seed 33 — seed33_best.pth
#   Head : CE  |  Training best val QWK: 0.8972
#   Evaluating ...
#     batch 12/12
#   QWK=0.8845 | Acc=82.83% | MAE=0.2316 | RMSE=0.6110
#
#   Seed 81 — seed81_best.pth
#   Head : CE  |  Training best val QWK: 0.9089
#   Evaluating ...
#     batch 12/12
#   QWK=0.8798 | Acc=83.65% | MAE=0.2262 | RMSE=0.6154
#
#   Seed 5 — seed5_best.pth
#   Head : CE  |  Training best val QWK: 0.8935
#   Evaluating ...
# ...

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification/05_results/eval_multikd.py"
# Out:
# ...
#   04_kd_multi — Student + Teacher Evaluation
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification\05_results
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification\_dataset_extracted
#   Test samples : 367
#
#
# ############################################################################
#   STUDENT MODELS
# ############################################################################
#
#
# ...
#   Multi-Teacher KD — Nominal CE  (ResNet-50-CE + EffNetB3-CE → MobileNetV3-Small)
# ...
#
#   Seed 33 — kd_seed33_best.pth
#   Head : CE  |  Training best val QWK: 0.9003
#   Evaluating ...
#     batch 12/12
#   QWK=0.8832 | Acc=82.02% | MAE=0.2371 | RMSE=0.6110
#
#   Seed 81 — kd_seed81_best.pth
#   Head : CE  |  Training best val QWK: 0.8929
#   Evaluating ...
#     batch 12/12
#   QWK=0.8552 | Acc=80.65% | MAE=0.2752 | RMSE=0.6905
#
#   Seed 5 — kd_seed5_best.pth
# ...
