# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification/05_results/eval_singlekd.py"
# Out:
# ============================================================================
#   03_kd_single — Student Evaluation
# ============================================================================
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification\05_results
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification\_dataset_extracted
#   Test samples : 367
#
#
# ============================================================================
#   Single-Teacher KD — CE  (ResNet-50-CE → MobileNetV3-Small)
# ============================================================================
#
#   Seed 33 — seed33_resume.pth
#   Head : CE  |  Training best val QWK: 0.8972
#   Evaluating ...
#     batch 12/12
#   QWK=0.8859 | Acc=82.83% | MAE=0.2316 | RMSE=0.6065
#
#   Seed 81 — seed81_resume.pth
#   Head : CE  |  Training best val QWK: 0.9089
#   Evaluating ...
#     batch 12/12
#   QWK=0.8748 | Acc=83.11% | MAE=0.2343 | RMSE=0.6307
#
#   Seed 5 — seed5_resume.pth
#   Head : CE  |  Training best val QWK: 0.8935
#   Evaluating ...
#     batch 12/12
#   QWK=0.8836 | Acc=83.92% | MAE=0.2207 | RMSE=0.6065
#
#   Saved → single_ce_test_results.txt
#
#
# ============================================================================
#   Single-Teacher KD — CORAL  (ResNet-50-CORAL → MobileNetV3-Small)
# ============================================================================
#
#   Seed 33 — student_seed33_resume.pth
#   Head : CORAL  |  Training best val QWK: 0.9098
#   Evaluating ...
#     batch 12/12
#   QWK=0.8823 | Acc=82.83% | MAE=0.2289 | RMSE=0.6087
#
#   Seed 81 — student_seed81_resume.pth
#   Head : CORAL  |  Training best val QWK: 0.9025
#   Evaluating ...
#     batch 12/12
#   QWK=0.8780 | Acc=82.56% | MAE=0.2343 | RMSE=0.6132
#
#   Seed 5 — student_seed5_resume.pth
#   Head : CORAL  |  Training best val QWK: 0.9038
#   Evaluating ...
#     batch 12/12
#   QWK=0.8738 | Acc=80.93% | MAE=0.2480 | RMSE=0.6198
#
#   Saved → single_coral_test_results.txt
#
#
# ============================================================================
#   SUMMARY — 03_kd_single  (mean ± std across seeds)
# ============================================================================
#   Scenario                                    QWK        Acc (%)       Macro F1
#   ──────────────────────────────────────────────────────────────────────────
#   single_ce                      0.8814±0.0048   83.29±0.46   0.6895±0.0051
#   single_coral                   0.8780±0.0035   82.11±0.84   0.6563±0.0185
# ============================================================================
#
#   Summary → single_kd_summary.txt
#   CSV     → single_kd_results.csv
#
# Done.

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/dr-classification/05_results/eval_multikd.py"
# Out:
# ============================================================================
#   04_kd_multi — Student Evaluation
# ============================================================================
#   Project root : D:\UNI\TUGAS-AKHIR\code\dr-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\dr-classification\05_results
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\dr-classification\_dataset_extracted
#   Test samples : 367
#
#
# ============================================================================
#   Multi-Teacher KD — Nominal CE  (ResNet-50-CE + EffNetB3-CE → MobileNetV3-Small)
# ============================================================================
#
#   Seed 33 — kd_seed33_resume.pth
#   Head : CE  |  Training best val QWK: 0.9003
#   Evaluating ...
#     batch 12/12
#   QWK=0.8876 | Acc=82.29% | MAE=0.2316 | RMSE=0.6020
#
#   Seed 81 — kd_seed81_resume.pth
#   Head : CE  |  Training best val QWK: 0.8929
#   Evaluating ...
#     batch 12/12
#   QWK=0.8663 | Acc=82.56% | MAE=0.2507 | RMSE=0.6561
#
#   Seed 5 — kd_seed5_resume.pth
#   Head : CE  |  Training best val QWK: 0.8958
#   Evaluating ...
#     batch 12/12
#   QWK=0.8664 | Acc=81.20% | MAE=0.2589 | RMSE=0.6499
#
#   Saved → multi_nominal_resnet50_effnetb3_test_results.txt
#
#
# ============================================================================
#   Multi-Teacher KD — Ordinal CORAL  (ResNet-50-CORAL + EffNetB3-CORAL → MobileNetV3-Small)
# ============================================================================
#
#   Seed 33 — coral_kd_seed33_resume.pth
#   Head : CORAL  |  Training best val QWK: 0.9159
#   Evaluating ...
#     batch 12/12
#   QWK=0.8860 | Acc=82.02% | MAE=0.2289 | RMSE=0.5906
#
#   Seed 81 — coral_kd_seed81_resume.pth
#   Head : CORAL  |  Training best val QWK: 0.9014
#   Evaluating ...
#     batch 12/12
#   QWK=0.8814 | Acc=81.47% | MAE=0.2398 | RMSE=0.6087
#
#   Seed 5 — coral_kd_seed5_resume.pth
#   Head : CORAL  |  Training best val QWK: 0.9094
#   Evaluating ...
#     batch 12/12
#   QWK=0.8831 | Acc=81.20% | MAE=0.2371 | RMSE=0.6020
#
#   Saved → multi_ordinal_resnet50_effnetb3_test_results.txt
#
#
# ============================================================================
#   Multi-Teacher KD — Hybrid CA-MKD  (ResNet-50-CE + EffNetB3-CORAL → MobileNetV3-Small)
# ============================================================================
#
#   Seed 33 — hybrid_camkd_seed33_resume.pth
#   Head : CE  |  Training best val QWK: 0.9111
#   Evaluating ...
#     batch 12/12
#   QWK=0.8993 | Acc=85.01% | MAE=0.1989 | RMSE=0.5598
#
#   Seed 81 — hybrid_camkd_seed81_resume.pth
#   Head : CE  |  Training best val QWK: 0.9045
#   Evaluating ...
#     batch 12/12
#   QWK=0.8817 | Acc=82.83% | MAE=0.2316 | RMSE=0.6110
#
#   Seed 5 — hybrid_camkd_seed5_resume.pth
#   Head : CE  |  Training best val QWK: 0.9052
#   Evaluating ...
#     batch 12/12
#   QWK=0.8849 | Acc=83.38% | MAE=0.2234 | RMSE=0.6043
#
#   Saved → multi_hybrid_resnet50_effnetb3_test_results.txt
#
#
# ============================================================================
#   Multi-Teacher KD — Hybrid CA-MKD  (ResNet-50-CE + ResNet-50-CORAL → MobileNetV3-Small)
# ============================================================================
#
#   Seed 33 — hybridresnet50_camkd_seed33_resume.pth
#   Head : CE  |  Training best val QWK: 0.9088
#   Evaluating ...
#     batch 12/12
#   QWK=0.9028 | Acc=86.10% | MAE=0.1880 | RMSE=0.5598
#
#   Seed 81 — hybridresnet50_camkd_seed81_resume.pth
#   Head : CE  |  Training best val QWK: 0.9112
#   Evaluating ...
#     batch 12/12
#   QWK=0.8847 | Acc=83.92% | MAE=0.2207 | RMSE=0.6065
#
#   Seed 5 — hybridresnet50_camkd_seed5_resume.pth
#   Head : CE  |  Training best val QWK: 0.9079
#   Evaluating ...
#     batch 12/12
#   QWK=0.8817 | Acc=82.02% | MAE=0.2371 | RMSE=0.6154
#
#   Saved → multi_hybrid_resnet50_resnet50_test_results.txt
#
#
# ============================================================================
#   SUMMARY — 04_kd_multi  (mean ± std across seeds)
# ============================================================================
#   Scenario                                                QWK      Acc (%)     Macro F1
#   ──────────────────────────────────────────────────────────────────────────
#   multi_nominal_resnet50_effnetb3            0.8734±0.0100   82.02±0.59   0.6779±0.0108
#   multi_ordinal_resnet50_effnetb3            0.8835±0.0019   81.56±0.34   0.6325±0.0108
#   multi_hybrid_resnet50_effnetb3             0.8886±0.0076   83.74±0.93   0.7028±0.0198
#   multi_hybrid_resnet50_resnet50             0.8897±0.0093   84.01±1.67   0.7045±0.0237
# ============================================================================
#
#   Summary → multi_kd_summary.txt
#   CSV     → multi_kd_results.csv
#
# Done.
